# %%
import pandas as pd
df= pd.read_csv("vins_vinatis_150_pages.csv")
import ast

# %%
# Ajout du préfixe à la colonne 'image'
df['image_url'] = "https://www.vinatis.com/" + df['image'].astype(str)

# Affichage des 5 premières URLs générées
print(df[['image', 'image_url']].head())

# Optionnel : sauvegarde dans un nouveau CSV
# df.to_csv("vinatis_data_with_image_urls.csv", index=False
# Out:
#                                                image  \
# 0  95769-fine_default/le-bal-des-papillons-2024-h...
# 1  80831-fine_default/lupo-meraviglia-tre-di-tre-...
# 2  94492-fine_default/colombard-sauvignon-2024-ho...
# 3  98180-fine_default/n3-colombard-sauvignon-blan...
# 4          95662-fine_default/rose-2024-horgelus.png
#
#                                            image_url
# 0  https://www.vinatis.com/95769-fine_default/le-...
# 1  https://www.vinatis.com/80831-fine_default/lup...
# 2  https://www.vinatis.com/94492-fine_default/col...
# 3  https://www.vinatis.com/98180-fine_default/n3-...
# 4  https://www.vinatis.com/95662-fine_default/ros...

# %%
df.columns
# Out:
# Index(['other_products', 'features', 'advanced_stock_management', 'contenance',
#        'indice_comportementale', 'id', 'affichage_special_pack', 'disponible',
#        'image', 'accroche', 'franco', 'weight', 'active', 'id_manufacturer',
#        'nbvote_product', 'cuvee_type', 'achat_oneshot', 'labels',
#        'online_only', 'id_product_redirected', 'suivi', 'note_sur_20', 'name',
#        'prix_propriete', 'cache_is_pack', 'rewards', 'is_virtual',
#        'out_of_stock', 'note_product', 'additional_shipping_cost',
#        'best_sales', 'physique', 'allocation_annuelle', 'description',
#        'stocks', 'id_cuvee', 'minimal_quantity', 'animations', 'quantity_max',
#        'categories', 'libelle_prix_propriete', 'last_date_visibility_active',
#        'link_rewrite', 'active_description', 'nous_contacter',
#        'buy_by_multiple', 'available_for_order', 'manufacturer_name',
#        'no_animation', 'date_add', 'description_short', 'abv',
#        'cuvee_type_name', 'subtitle_with_link', 'comment', 'providers',
#        'subtitle_without_link', 'prices', 'pricePerLiter', 'nutritional_data',
#        'id_stock_booked', 'image_url'],
#       dtype='object')

# %%
df.head()
# Out:
#                                       other_products  \
# 0  [{'id_image': 95769, 'vintage': 2024, 'id': 73...
# 1  [{'id_image': 80831, 'vintage': 2022, 'id': 63...
# 2  [{'id_image': 94492, 'vintage': 2024, 'id': 72...
# 3  [{'id_image': 98180, 'vintage': 2024, 'id': 75...
# 4  [{'id_image': 95662, 'vintage': 2024, 'id': 72...
#
#                                             features  \
# 0  {'country': 'France', 'allergen': False, 'tast...
# 1  {'country': 'Italie', 'allergen': False, 'tast...
# 2  {'emballage_d_origine': 'AUCUN', 'country': 'F...
# 3  {'country': 'France', 'allergen': False, 'tast...
# 4  {'country': 'France', 'allergen': False, 'tast...
#
#    advanced_stock_management  contenance  indice_comportementale     id  \
# 0                          0        0.75                      37  73560
# 1                          0        0.75                      37  63000
# 2                          0        0.75                      37  72739
# 3                          0        0.75                      37  75247
# 4                          0        0.75                      36  72413
#
#    affichage_special_pack  disponible  \
# 0                   False        3319
# 1                   False       23573
# 2                   False       12417
# 3                   False        6587
# 4                   False        2896
#
#                                                image  \
# 0  95769-fine_default/le-bal-des-papillons-2024-h...
# 1  80831-fine_default/lupo-meraviglia-tre-di-tre-...
# 2  94492-fine_default/colombard-sauvignon-2024-ho...
# 3  98180-fine_default/n3-colombard-sauvignon-blan...
# 4          95662-fine_default/rose-2024-horgelus.png
#
#                                             accroche  ...  cuvee_type_name  \
# 0  Plongez dans un univers de légèreté et d’éléga...  ...           Négoce
# 1  Une étoile montante des Pouilles vinifiée selo...  ...           Négoce
# 2  Savoureux <a class="maillage" href ="/vin-d-ho...  ...           Négoce
# 3  La référence incontestable des Côtes de <a cla...  ...           Négoce
# 4  Découvrez un rosé des plus gourmands au rappor...  ...           Négoce
#
#                                   subtitle_with_link  \
# 0  <a class="maillage" href ="/achat-vin-sud-oues...
# 1  <a class="maillage" href ="/achat-vin-italie">...
# 2  <a class="maillage" href ="/achat-vin-sud-oues...
# 3  <a class="maillage" href ="/achat-vin-sud-oues...
# 4  <a class="maillage" href ="/achat-vin-sud-oues...
#
#                                              comment  providers  \
# 0  {'date_add': '2025-05-11 21:28:22', 'wineWaite...      [659]
# 1  {'date_add': '2025-05-28 11:51:21', 'wineWaite...      [158]
# 2  {'date_add': '2025-04-24 08:16:16', 'wineWaite...      [659]
# 3  {'date_add': '2025-05-06 16:37:28', 'wineWaite...      [253]
# 4  {'date_add': '2025-04-28 14:17:58', 'wineWaite...      [659]
#
#                subtitle_without_link  \
# 0  Sud-Ouest / Côtes de Gascogne IGP
# 1                Italie / Puglia IGT
# 2  Sud-Ouest / Côtes de Gascogne IGP
# 3  Sud-Ouest / Côtes de Gascogne IGP
# 4  Sud-Ouest / Côtes de Gascogne IGP
#
#                                               prices  pricePerLiter  \
# 0  {'discount_quantities': [6], 'best_promo': 15,...          11.47
# 1  {'discount_quantities': [3], 'best_promo': 15,...          14.53
# 2  {'discount_quantities': [6], 'best_promo': 15,...           8.80
# 3  {'discount_quantities': [6], 'best_promo': 12,...           8.67
# 4  {'discount_quantities': [6], 'best_promo': 16,...           8.27
#
#   nutritional_data  id_stock_booked  \
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN
#
#                                            image_url
# 0  https://www.vinatis.com/95769-fine_default/le-...
# 1  https://www.vinatis.com/80831-fine_default/lup...
# 2  https://www.vinatis.com/94492-fine_default/col...
# 3  https://www.vinatis.com/98180-fine_default/n3-...
# 4  https://www.vinatis.com/95662-fine_default/ros...
#
# [5 rows x 62 columns]

# %%
def safe_literal_eval(val):
    if pd.isna(val):
        return {}
    try:
        return ast.literal_eval(val)
    except (ValueError, SyntaxError):
        return {}

def flatten_dict_columns(df, columns):
    for col in columns:
        # Convertir en dict de manière sûre
        df[col] = df[col].apply(safe_literal_eval)
        # Aplatir et préfixer
        flat = pd.json_normalize(df[col]).add_prefix(f'{col}_')
        df = pd.concat([df.drop(columns=[col]), flat], axis=1)
    return df

# Utilisation :
cols_to_flatten = ['features','prices','comment','other_products',]  # Ajoute les colonnes à aplatir
df = flatten_dict_columns(df, cols_to_flatten)
df.head()
# Out:
#    advanced_stock_management  contenance  indice_comportementale     id  \
# 0                          0        0.75                      37  73560
# 1                          0        0.75                      37  63000
# 2                          0        0.75                      37  72739
# 3                          0        0.75                      37  75247
# 4                          0        0.75                      36  72413
#
#    affichage_special_pack  disponible  \
# 0                   False        3319
# 1                   False       23573
# 2                   False       12417
# 3                   False        6587
# 4                   False        2896
#
#                                                image  \
# 0  95769-fine_default/le-bal-des-papillons-2024-h...
# 1  80831-fine_default/lupo-meraviglia-tre-di-tre-...
# 2  94492-fine_default/colombard-sauvignon-2024-ho...
# 3  98180-fine_default/n3-colombard-sauvignon-blan...
# 4          95662-fine_default/rose-2024-horgelus.png
#
#                                             accroche  franco  weight  ...  \
# 0  Plongez dans un univers de légèreté et d’éléga...    True    1.19  ...
# 1  Une étoile montante des Pouilles vinifiée selo...    True    1.17  ...
# 2  Savoureux <a class="maillage" href ="/vin-d-ho...   False    1.18  ...
# 3  La référence incontestable des Côtes de <a cla...   False    1.15  ...
# 4  Découvrez un rosé des plus gourmands au rappor...   False    1.18  ...
#
#    comment_source_shop  comment_note_sur_20  \
# 0                  0.0                  NaN
# 1                  0.0                  NaN
# 2                  0.0                  NaN
# 3                  0.0                  NaN
# 4                  0.0                  NaN
#
#                                     other_products_0  \
# 0  {'id_image': 95769, 'vintage': 2024, 'id': 735...
# 1  {'id_image': 80831, 'vintage': 2022, 'id': 630...
# 2  {'id_image': 94492, 'vintage': 2024, 'id': 727...
# 3  {'id_image': 98180, 'vintage': 2024, 'id': 752...
# 4  {'id_image': 95662, 'vintage': 2024, 'id': 724...
#
#                                     other_products_1  other_products_2  \
# 0                                               None              None
# 1  {'id_image': 86870, 'vintage': 2022, 'id': 666...              None
# 2                                               None              None
# 3                                               None              None
# 4                                               None              None
#
#   other_products_3  other_products_4  other_products_5  other_products_6  \
# 0             None              None              None              None
# 1             None              None              None              None
# 2             None              None              None              None
# 3             None              None              None              None
# 4             None              None              None              None
#
#    other_products_7
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
#
# [5 rows x 127 columns]

# %%
list(df.columns)
# Out:
# ['advanced_stock_management',
#  'contenance',
#  'indice_comportementale',
#  'id',
#  'affichage_special_pack',
#  'disponible',
#  'image',
#  'accroche',
#  'franco',
#  'weight',
#  'active',
#  'id_manufacturer',
#  'nbvote_product',
#  'cuvee_type',
#  'achat_oneshot',
#  'labels',
#  'online_only',
#  'id_product_redirected',
#  'suivi',
#  'note_sur_20',
#  'name',
#  'prix_propriete',
#  'cache_is_pack',
#  'rewards',
#  'is_virtual',
#  'out_of_stock',
#  'note_product',
#  'additional_shipping_cost',
#  'best_sales',
#  'physique',
#  'allocation_annuelle',
#  'description',
#  'stocks',
#  'id_cuvee',
#  'minimal_quantity',
#  'animations',
#  'quantity_max',
#  'categories',
#  'libelle_prix_propriete',
#  'last_date_visibility_active',
#  'link_rewrite',
#  'active_description',
#  'nous_contacter',
#  'buy_by_multiple',
#  'available_for_order',
#  'manufacturer_name',
#  'no_animation',
#  'date_add',
#  'description_short',
#  'abv',
#  'cuvee_type_name',
#  'subtitle_with_link',
#  'providers',
#  'subtitle_without_link',
#  'pricePerLiter',
#  'nutritional_data',
#  'id_stock_booked',
#  'image_url',
#  'features_country',
#  'features_allergen',
#  'features_taste',
#  'features_food_and_wine_matching',
#  'features_recommended_with',
#  'features_type',
#  'features_smell',
#  'features_capacity',
#  'features_character',
#  'features_sight',
#  'features_sortable_vintage',
#  'features_appellation',
#  'features_grape_variety',
#  'features_emballage_d_origine',
#  'features_service_temperature',
#  'features_flatened',
#  'features_colour',
#  'features_abv',
#  'features_vintage',
#  'features_service',
#  'features_storage_instructions',
#  'features_region',
#  'features_taste_style',
#  'features_appellation_type',
#  'features_all_grapes',
#  'features_to_drink_until',
#  'features_bottle_stopper',
#  'features_pictos',
#  'features_images',
#  'features_full_grape_variety',
#  'features_bio',
#  'features_to_drink_from',
#  'features_wine_classification',
#  'features_type_coffret',
#  'features_fine_wine',
#  'features_champagne_type',
#  'features_whisky_style',
#  'features_spirits_type',
#  'features_nombre_de_bouteilles',
#  'features_beer_type',
#  'prices_discount_quantities',
#  'prices_best_promo',
#  'prices_best_conditionnement',
#  'prices_manuel',
#  'prices_salable',
#  'prices_isVF',
#  'prices_is_country_restricted',
#  'prices_promotions',
#  'prices_id_country',
#  'prices_price',
#  'prices_is_group_restricted',
#  'prices_isPP',
#  'prices_id_group',
#  'prices_best_price',
#  'comment_date_add',
#  'comment_wineWaiter',
#  'comment_source_domain',
#  'comment_customer_name',
#  'comment_content',
#  'comment_source_shop',
#  'comment_note_sur_20',
#  'other_products_0',
#  'other_products_1',
#  'other_products_2',
#  'other_products_3',
#  'other_products_4',
#  'other_products_5',
#  'other_products_6',
#  'other_products_7']

# %%
df.describe()
# Out:
#        advanced_stock_management   contenance  indice_comportementale  \
# count                     5075.0  5075.000000             5075.000000
# mean                         0.0     0.937799               11.449064
# std                          0.0     0.719554                7.804969
# min                          0.0     0.250000                1.000000
# 25%                          0.0     0.750000                4.000000
# 50%                          0.0     0.750000               11.000000
# 75%                          0.0     0.750000               16.000000
# max                          0.0     9.000000               37.000000
#
#                  id    disponible       weight  id_manufacturer  \
# count   5075.000000   5075.000000  5075.000000      5075.000000
# mean   66716.786601    207.267586     1.637594      1905.062857
# std    11518.068878    636.319764     1.274266      1357.389558
# min      742.000000    -24.000000     0.490000         0.000000
# 25%    64418.500000     18.000000     1.260000       444.500000
# 50%    70512.000000     62.000000     1.320000      1858.000000
# 75%    73809.500000    193.000000     1.400000      3058.000000
# max    77976.000000  23573.000000    22.810000      4298.000000
#
#        nbvote_product   cuvee_type  achat_oneshot  ...  \
# count     5075.000000  5075.000000    5075.000000  ...
# mean         5.080000     2.584631       0.021084  ...
# std         15.109621     0.819597       0.143678  ...
# min          0.000000     0.000000       0.000000  ...
# 25%          0.000000     2.000000       0.000000  ...
# 50%          1.000000     3.000000       0.000000  ...
# 75%          4.000000     3.000000       0.000000  ...
# max        487.000000     8.000000       1.000000  ...
#
#        features_to_drink_until  features_to_drink_from  prices_best_promo  \
# count              3988.000000              163.000000        5075.000000
# mean               2033.587763             2021.944785           5.869163
# std                   7.557460                3.430530           7.868689
# min                2025.000000             2012.000000         -29.000000
# 25%                2029.000000             2019.500000           0.000000
# 50%                2031.000000             2021.000000           0.000000
# 75%                2036.000000             2024.000000          14.000000
# max                2080.000000             2034.000000          33.000000
#
#        prices_best_conditionnement  prices_id_country  prices_price  \
# count                  5075.000000             5075.0   5075.000000
# mean                      1.403547                8.0     75.942205
# std                       0.823331                0.0    767.408782
# min                       1.000000                8.0      4.900000
# 25%                       1.000000                8.0     14.500000
# 50%                       1.000000                8.0     25.500000
# 75%                       2.000000                8.0     50.000000
# max                      12.000000                8.0  43000.000000
#
#        prices_id_group  prices_best_price  comment_source_shop  \
# count           5075.0        5075.000000          3914.000000
# mean               3.0          74.540754             0.164027
# std                0.0         767.437945             0.790419
# min                3.0           4.500360             0.000000
# 25%                3.0          12.949850             0.000000
# 50%                3.0          24.501800             0.000000
# 75%                3.0          48.999600             0.000000
# max                3.0       43000.000000             6.000000
#
#        comment_note_sur_20
# count          2038.000000
# mean             18.120707
# std               0.742928
# min              10.000000
# 25%              18.000000
# 50%              18.000000
# 75%              19.000000
# max              20.000000
#
# [8 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5075 entries, 0 to 5074
# Columns: 127 entries, advanced_stock_management to other_products_7
# dtypes: bool(18), float64(17), int64(22), object(70)
# memory usage: 4.3+ MB

# %%
# Sauvegarde du DataFrame au format CSV
df.to_csv('vins_vinatis_flat_complet.csv', index=False)
